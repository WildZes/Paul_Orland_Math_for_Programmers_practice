# %%
from vector_drawing import *

# %%
dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4), (-5,3), (-5,2), (-2,2), (-5,1),
                (-4,0), (-2,1), (-1,0), (0,-3), (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)]

# %%
draw(Points(*dino_vectors), Segment((6,4),(3,1)), Segment((3,1),(1,2)))

# %%
draw(Points(*dino_vectors), Polygon(*dino_vectors))

# %%
ex2_2_vector = [(2,-2)]
draw(Points(*ex2_2_vector), Arrow(*ex2_2_vector))

# %%
ex2_5_vectors = [(x, x**2) for x in range(-10, 11)]
draw(Points(*ex2_5_vectors))
#Solution from book
draw(
    Points(*[(x,x**2) for x in range(-10,11)]),
    grid=(1,10),
    nice_aspect_ratio=False
)
