# %%
# !wget https://raw.githubusercontent.com/WildZes/Paul_Orland_Math_for_Programmers_practice/main/03_Ascending_to_the_3d_world/draw3d.py
# !wget https://raw.githubusercontent.com/WildZes/Paul_Orland_Math_for_Programmers_practice/main/03_Ascending_to_the_3d_world/colors.py
# Out:
# --2022-07-14 13:46:03--  https://raw.githubusercontent.com/WildZes/Paul_Orland_Math_for_Programmers_practice/main/03_Ascending_to_the_3d_world/draw3d.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5550 (5.4K) [text/plain]
# Saving to: ‘draw3d.py’
#
# draw3d.py           100%[===================>]   5.42K  --.-KB/s    in 0s
#
# 2022-07-14 13:46:03 (51.5 MB/s) - ‘draw3d.py’ saved [5550/5550]
#
# --2022-07-14 13:46:03--  https://raw.githubusercontent.com/WildZes/Paul_Orland_Math_for_Programmers_practice/main/03_Ascending_to_the_3d_world/colors.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90 [text/plain]
# Saving to: ‘colors.py’
#
# colors.py           100%[===================>]      90  --.-KB/s    in 0s
#
# 2022-07-14 13:46:03 (4.21 MB/s) - ‘colors.py’ saved [90/90]

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from draw3d import *

# %%
# Exercise 3.1
draw3d(Arrow3D((-1,-2,2)), Box3D(-1,-2,2))

# %%
# Exercise 3.2—Mini Project
tops = set([(x,y,z) for x in [1,-1] for y in [1,-1] for z in [1,-1]])
segments = []
for dot1 in list(tops):
  for dot2 in list(tops):
    count = 0
    for i in range(len(dot1)):
      if dot1[i]==dot2[i]:
        count += 1
    if count == 2:
      segments.append(Segment3D(dot1,dot2))
draw3d(*segments)

# %%
# Solution from the book
pm1 = [1,-1]
vertices = [(x,y,z) for x in pm1 for y in pm1 for z in pm1]
edges = [((-1,y,z),(1,y,z)) for y in pm1 for z in pm1] +\
[((x,-1,z),(x,1,z)) for x in pm1 for z in pm1] +\
[((x,y,-1),(x,y,1)) for x in pm1 for y in pm1]
draw3d(
Points3D(*vertices,color=blue),
*[Segment3D(*edge) for edge in edges]
)
